# %% [markdown]
# <a href="https://colab.research.google.com/github/jayeoung/kaggle/blob/master/kaggle_titanic_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 패키지

# %%
#패키지 설치
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5) #글씨 설정 미리 지정하기

import missingno as msno
import warnings
warnings.filterwarnings('ignore') #경고 무시하기 설정

# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## train, test csv 삽입

# %%
#드라이브 마운트, 인증코드 받기
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#csv 불러오기. 드라이브 경로 이용
#이따가 위에 드라이브 마운트 경로 정리해야지
df_train =pd.read_csv("/content/drive/My Drive/Colab Notebooks/train.csv")
df_test = pd.read_csv("/content/drive/My Drive/Colab Notebooks/test.csv")

# %% [markdown]
# ## 다른 커리큘럼 캐글 타이타닉

# %%
import pandas as pd
#판다스 이용하기

train=pd.read_csv('train.csv') #train 파일 불러오기

train.head() #train 파일의 윗 5줄 보기
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
sns.relplot(data=train,x='Age',y='Survived')

# %%
sns.relplot(data=train,x='Age',y='Survived',hue='Sex',aspect=3)

# %%
sns.catplot(data=train, x='Pclass', y='Fare',aspect=4)
#차이를 직접 확인해봐라?

sns.catplot(data=train,x='Pclass',y='Fare',jitter=False, aspect=4)
sns.catplot(data=train,x='Pclass',y='Fare',aspect=4,hue='Sex')

# %%
sns.catplot(data=train,x='Pclass',y='Fare',kind='box')
sns.catplot(data=train,x='Pclass',y='Fare',kind='box',hue='Sex')

# %%
sns.pairplot(data=train,hue='Sex',
            x_vars=['Pclass','Age','Fare'],
            y_vars=['Survived','Age','Fare'],height=3)

# %%
cnt=train[train['Sex']=='male'].shape[0]
print(cnt)
# Out:
# 577

# %%
cnt=train[train['Pclass']==1].shape[0]
print(cnt)
# Out:
# 216

# %%
import pandas as pd
train=pd.read_csv('train.csv')
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# !ls
# Out:
# drive  sample_data

# %%
import pandas as pd
train=pd.read_csv('train.csv')
train

#사망자 수 세기
cnt=train[train['Survived']==0].shape[0]
print(cnt)

#생존자 수 세기
cnt=train[train['Survived']==1].shape[0]
print(cnt)

#matplotlib에서 bar chart를 그리는 명령어는? 실행후 plt.show()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Summary Statistics
## 사망자,생존자 수 
train_sum_by_survived = train.groupby('Survived').Survived.sum()

label = ['Survived','Death']
index = np.arange(len(label))

plt.bar(index, train_sum_by_survived)
plt.title('The number of Survived or Death', fontsize=20)
plt.xlabel('Survived', fontsize=18)
plt.ylabel('The number', fontsize=18)
plt.xticks(index, label, fontsize=15)
plt.show()

# 0은 사망 1은 생존. 사망자 수는 0의 갯수 구하기, 생존자 수는 합하던가 갯수 구하기
# 카운트를 해야 하나?



#2단계) 범례, 축 이름, 막대 색 설정할 때 쓰는 구문은?
# Out:
# 549
# 342
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # 1.데이터셋 확인
# ## 1.1 Null data check

# %% [markdown]
# ### 시작할때 : 패키지 설치, 드라이브 마운트, csv 불러오기

# %%
#패키지
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5)

import missingno as msno

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
#드라이브 마운트, 인증코드 받기
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#csv 불러오기. 드라이브 경로 이용
#이따가 위에 드라이브 마운트 경로 정리해야지
df_train =pd.read_csv("/content/drive/My Drive/Colab Notebooks/train.csv")
df_test = pd.read_csv("/content/drive/My Drive/Colab Notebooks/test.csv")

# %% [markdown]
# ### 데이터 분석 시작

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df_test.head()
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
for col in df_train.columns:
  msg='column: {:>10}\t Percent of NaN value: {:.2f}%'.format(col,100*(df_train[col].isnull().sum()/df_train[col].shape[0]))

  print(msg)
# Out:
# column: PassengerId	 Percent of NaN value: 0.00%
# column:   Survived	 Percent of NaN value: 0.00%
# column:     Pclass	 Percent of NaN value: 0.00%
# column:       Name	 Percent of NaN value: 0.00%
# column:        Sex	 Percent of NaN value: 0.00%
# column:        Age	 Percent of NaN value: 19.87%
# column:      SibSp	 Percent of NaN value: 0.00%
# column:      Parch	 Percent of NaN value: 0.00%
# column:     Ticket	 Percent of NaN value: 0.00%
# column:       Fare	 Percent of NaN value: 0.00%
# column:      Cabin	 Percent of NaN value: 77.10%
# column:   Embarked	 Percent of NaN value: 0.22%

# %%
for col in df_test.columns:
  msg='column:{:>10}\t Percent of NaN value: {:.2f}%'.format(col, 100*(df_test[col].isnull().sum()/df_test[col].shape[0]))

  print(msg)
# Out:
# column:PassengerId	 Percent of NaN value: 0.00%
# column:    Pclass	 Percent of NaN value: 0.00%
# column:      Name	 Percent of NaN value: 0.00%
# column:       Sex	 Percent of NaN value: 0.00%
# column:       Age	 Percent of NaN value: 20.57%
# column:     SibSp	 Percent of NaN value: 0.00%
# column:     Parch	 Percent of NaN value: 0.00%
# column:    Ticket	 Percent of NaN value: 0.00%
# column:      Fare	 Percent of NaN value: 0.24%
# column:     Cabin	 Percent of NaN value: 78.23%
# column:  Embarked	 Percent of NaN value: 0.00%

# %%
msno.matrix(df=df_train.iloc[:, :], figsize=(8,8), color=(0.8, 0.5, 0.2))

# %%
msno.bar(df=df_train.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2))

# %%
msno.bar(df=df_test.iloc[:, :], figsize=(8,8), color=(0.8, 0.5, 0.2))

# %% [markdown]
# https://kaggle-kr.tistory.com/17?category=868316

# %% [markdown]
# ## 1.2 Target label 확인

# %%
# 우리의 target label은 survived. 즉 생존율을 예측하는 것이다.
# 지금 같은 binary classification 
문제에서는 1, 0의 분포가 어떠냐에 따라 모델 평가 방법이 달라질 수 있다

# %%
f, ax=plt.subplots(1,2, figsize=(18,8))

df_train['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct="%1.1f%%", ax=ax[0], shadow=True)
ax[0].set_title('Pie plot - Survived')
ax[0].set_ylabel('')
sns.countplot('Survived', data=df_train,ax=ax[1])
ax[1].set_title('Count plot - Survived')

plt.show()

# %% [markdown]
# # 2. Exploratory data analysis
#
# ## 2.1 Pclass

# %%
#pclass는 ordinal. 서수형 데이터. 배에 탑승 등급?

# %%
import pandas as pd
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df_test.head()
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'],as_index=True).count()

#pclass랑 survived 가져와서 pclass로 묶기, pclass에 0,1 이 count 되는데 각 pclass 별 생존률
# count() 하면 class에 몇명 있는지
# sum()하면 생존한 사람(survived =1) 사람의 총합을 구하게 된다
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'],as_index=True).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
pd.crosstab(df_train['Pclass'],df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')

#위의 과정을 한번에 보여주는 crosstab 기능
# Out:
# <style  type="text/css" >
#     #T_1a051828_ab09_11ea_a5b5_0242ac1c0002row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1a051828_ab09_11ea_a5b5_0242ac1c0002row0_col1 {
#             background-color:  #cee666;
#             color:  #000000;
#         }    #T_1a051828_ab09_11ea_a5b5_0242ac1c0002row0_col2 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_1a051828_ab09_11ea_a5b5_0242ac1c0002row1_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_1a051828_ab09_11ea_a5b5_0242ac1c0002row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1a051828_ab09_11ea_a5b5_0242ac1c0002row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1a051828_ab09_11ea_a5b5_0242ac1c0002row2_col0 {
#             background-color:  #60b066;
#             color:  #000000;
# ...

# %% [markdown]
# grouped 객체에 mean() 평균내기? 를 하면 각 클래스별 생존률 얻을 수 있다.
# 생존자(survived=1)/전체(all)

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'],as_index=True).mean().sort_values(by='Survived',ascending=False).plot.bar()

# %% [markdown]
# 이건 pclass가 높을 수록 생존률이 높다는 걸 알 수 있다.
# seaborn의 countplot을 이용해서 label에 따른 개수 확인해보기

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

y_position=1.02
f, ax=plt.subplots(1,2,figsize=(18,8))
df_train['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'], ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass',y=y_position,color='white')
ax[0].set_ylabel('Count',color='white')
sns.countplot('Pclass',hue='Survived', data=df_train,ax=ax[1])
ax[1].set_title('Pclass: Survived vs Dead',y=y_position,color='white')
plt.show()

# %% [markdown]
# 클래스가 높을 수록 생존확률이 높다는 것을 확인
# pclass 1,2,3 순서대로 63%, 48%, 25%
# 우리는 생존에 pclass가 큰 영향을 미친다고 생각해 볼 수 있고
# 나중에 모델을 세울 때 이 feature를 사용하는 것이 좋을 것이라 판단해볼 수 있다

# %% [markdown]
# ## 2.2 Sex

# %% [markdown]
# 이번에는 성별 변수로 생존률 확인해보자
# pandas groupby랑 seaborn countplot을 사용해서 시각화해보자

# %%
f, ax=plt.subplots(1,2, figsize=(18,8))
df_train[['Sex','Survived']].groupby(['Sex'],as_index=True).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex', color='white')

sns.countplot('Sex', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')
plt.show()

# %% [markdown]
# 여자가 생존할 확률이 높았다

# %%
df_train[['Sex','Survived']].groupby(['Sex'],as_index=False).mean().sort_values(by='Survived',ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
pd.crosstab(df_train['Sex'],df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_5cdfd43c_abf2_11ea_a728_0242ac1c0002row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_5cdfd43c_abf2_11ea_a728_0242ac1c0002row0_col1 {
#             background-color:  #77bb66;
#             color:  #000000;
#         }    #T_5cdfd43c_abf2_11ea_a728_0242ac1c0002row0_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_5cdfd43c_abf2_11ea_a728_0242ac1c0002row1_col0 {
#             background-color:  #2c9666;
#             color:  #000000;
#         }    #T_5cdfd43c_abf2_11ea_a728_0242ac1c0002row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_5cdfd43c_abf2_11ea_a728_0242ac1c0002row1_col2 {
#             background-color:  #8bc566;
#             color:  #000000;
#         }    #T_5cdfd43c_abf2_11ea_a728_0242ac1c0002row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# pclass 처럼 sex도 예측모델에 쓰일 중요한 feature임을 알수있다.

# %% [markdown]
# ## 2.3 Both Sex and Pclass

# %% [markdown]
#  sex, pclass 두가지에 관해 생존이 어떻게 달라지는지 확인하기
#  seaborn의 factorplot을 이용하면 손쉽게 3개 차원으로 이뤄진 그래프 그릴 수 있다.

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=df_train, size=6, aspect=1.5)

# %% [markdown]
# 모든 클래스에서 female이 살 확률이 male보다 높다.
#
# 여,남 상관없이 클래스 높을 수록 살 확률 높다
#
# 위 그래프는 hue 대신 column으로 하면 아래와 같아진다.

# %%
sns.factorplot(x='Sex',y='Survived', col='Pclass',data=df_train, satureation=.5, size=9, aspect=1)

# %% [markdown]
# ## 2.4 Age

# %% [markdown]
# Age feature을 살펴보자

# %%
print('제일 나이 많은 탑승객:{:.1f} Years'.format(df_train['Age'].max()))
print('제일 나이 어린 탑승객:{:.1f} Years'.format(df_train['Age'].min()))
print('탑승객 평균 나이:{:.1f}.Years'.format(df_train['Age'].mean()))
# Out:
# 제일 나이 많은 탑승객:80.0 Years
# 제일 나이 어린 탑승객:0.4 Years
# 탑승객 평균 나이:29.7.Years

# %% [markdown]
# 생존에 따른 Age의 histogram을 그려보자

# %%
fig, ax =plt.subplots(1,1,figsize=(9,5))
sns.kdeplot(df_train[df_train['Survived']==1]['Age'],ax=ax)
sns.kdeplot(df_train[df_train['Survived']==0]['Age'],ax=ax)
plt.legend(['Survived==1','Survived == 0'])
plt.show()

# %% [markdown]
# 위에서 생존자 중 나이가 어린 경우가 많음을 볼 수 있다.

# %%
#Age distribution withing classes
plt.figure(figsize=(8,6))
df_train['Age'][df_train['Pclass']==1].plot(kind='kde')
df_train['Age'][df_train['Pclass']==2].plot(kind='kde')
df_train['Age'][df_train['Pclass']==3].plot(kind='kde')

plt.xlabel('Age')
plt.title('Age Distribution within classes')
plt.legend(['1st Class','2nd Class','3rd Class'])

# %% [markdown]
# *   Class가 높을 수록 나이 많은 사람의 비중이 커짐
# *   나이대가 변하면서 생존률이 어떻게 되는 지 보려고 합니다.
# *   나이 범위를 넓혀가면서 생존률이 어떻게 되는지 봅시다.

# %%
cummulate_survival_ratio =[]
for i in range(1,80):
  cummulate_survival_ratio.append(df_train[df_train['Age']<i]['Survived'].sum()/len(df_train[df_train['Age']<i]['Survived']))

plt.figure(figsize=(7,7))
plt.plot(cummulate_survival_ratio)
plt.title('Survival rate change depending on range of Age',y=1.02)
plt.ylabel('Survival rate')
plt.xlabel('Range of Age(0~x)')
plt.show()

# %% [markdown]
# *   나이가 어릴 수록 생존률이 높다
# *   나이가 중요한 feature로 쓰일 수 있다

# %% [markdown]
# ## 2.5 Pclass, Sex, Age
#
#
#
# *   지금까지 본 Sex, Pclass, Age, Survived 모두에 대해 보고싶다. 이걸 쉽게 그려주는 것이 seaborn의 violinplot이다.
# *   x축은 우리가 나눠서 보고싶은 case(여기선 Pclass, Sex)를 나타내고, y축은 보고싶어하는 distribution(Age)이다.

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age",hue="Survived",data=df_train,scale='count',split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age",hue="Survived",data=df_train,scale='count',split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# *   왼쪽 그림은 Pclass 별로 Age의 distribution이 어떻게 다른지, 거기에 생존여부에 따라 구분한 그래프이다.
# *   오른쪽 그림도 Sex, 생존에 따른 distribution이 어떻게 다른지 보여주는 그래프이다.
#
#
# *   생존만 봤을 때, 모든 클래스에서 나이가 어릴 수록 생존을 많이 한 것을 볼 수 있다.
# *   오른쪽 그림에서 보면 여자가 생존을 많이 한 것을 볼 수 있다.
#
#
# *   여성과 아이를 먼저 챙긴 것으로 볼 수 있다.

# %% [markdown]
# ## 2.6 Embarked
#
#
# *   탑승한 항구를 나타냅니다.
# *   위에서처럼 탑승한 곳에 따른 생존률을 보겠습니다.

# %%
f,ax=plt.subplots(1,1,figsize=(7,7))
df_train[['Embarked','Survived']].groupby(['Embarked'],as_index=True).mean().sort_values(by='Survived',ascending=False).plot.bar(ax=ax)

# %% [markdown]
# *   조금의 차이는 있지만 생존률은 비슷하다. C가 제일 높다
# *   모델에 얼마나 큰 영향을 미칠지 모르겠지만, 사용해보겠다
# *   모델을 만들고 나면 우리가 사용한 feature들이 얼마나 중요한 역할을 했는지 확인해 볼 수 있다. 이는 추후에 모델을 만들고 난 다음에 살펴볼 것이다.
# *   다른 feature로 split하여 살펴보겠다.

# %%
f, ax=plt.subplots(2,2, figsize=(20,15))
sns.countplot('Embarked',data=df_train,ax=ax[0,0])
ax[0,0].set_title('(1) No. Of Passengers Boarded')
sns.countplot('Embarked',hue='Sex', data=df_train, ax=ax[0,1])
ax[0,1].set_title('(2) Male-Female Split for Embarked')
sns.countplot('Embarked', hue='Survived',data=df_train, ax=ax[1,0])
ax[1,0].set_title('(3) Embarked vs Survived')
sns.countplot('Embarked', hue='Pclass',data=df_train,ax=ax[1,1])
ax[1,1].set_title('(4) Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# Figure(1)- 전체적으로 S에서 가장 많은 사람이 탑승했습니다.
# Figure(2)- C와 Q는 남녀의 비율이 비슷하고, S는 남자가 더 많습니다.
# Figure(3)- 생존확률이 S 경우 많이 낮은 걸 볼 수 있습니다.(이전 그래프에서 봤었습니다)
# Figure(4)- Class로 split해서 보니, C가 생존확률이 높은 건 클래스가 높은 사람이 많이 타서 그렇습니다.S는 3rd class가 많아서 생존확률이 낮게 나옵니다.

# %% [markdown]
# ## 2.7 Family-SibSp(형제 자매) + Parch(부모, 자녀)
#
# SibSp와 Parch를 합하면 Family가 될 것이다.
# Family로 합쳐서 분석해보자

# %%
#패키지 설치
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5) #글씨 설정 미리 지정하기

import missingno as msno
import warnings
warnings.filterwarnings('ignore') #경고 무시하기 설정

# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#드라이브 마운트, 인증코드 받기
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#csv 불러오기. 드라이브 경로 이용
#이따가 위에 드라이브 마운트 경로 정리해야지
df_train =pd.read_csv("/content/drive/My Drive/Colab Notebooks/train.csv")
df_test = pd.read_csv("/content/drive/My Drive/Colab Notebooks/test.csv")

# %% [markdown]
# SibSp와 Parch를 합하면 Family가 될 것이다. Family로 합쳐서 분석해보자

# %%
#train set으로 Family 만들기 자신을 포함하려고 +1 해주자
df_train['FamilySize'] = df_train['SibSp'] + df_train['Parch'] +1

#test set으로 Family 만들기
#여기서도 자신을 포합하려고 +1 해주자
df_test["FamilySize"]=df_test['SibSp']+df_test["Parch"]+1

# %%
print("Maximum size of Family:", df_train['FamilySize'].max())
print("Minimum size of Family:", df_train['FamilySize'].min())
# Out:
# Maximum size of Family: 11
# Minimum size of Family: 1

# %% [markdown]
# FamilySize와 생존의 관계를 살펴보자

# %%
f,ax=plt.subplots(1,3,figsize=(40,10))
sns.countplot('FamilySize',data=df_train,ax=ax[0])
ax[0].set_title('(1) No. Of Passengers Boarded',y=1.02)

sns.countplot('FamilySize', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('(2) Survived countplot depending on FamilySize', y= 1.02)

df_train[['FamilySize','Survived']].groupby(['FamilySize'],as_index=True).mean().sort_values(by='Survived',ascending=False).plot.bar(ax=ax[2])
ax[2].set_title('(3) Survived rate depending on FamilySize', y=1.02)

plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# *   Figure(1) - 가족크기가 1~11까지 있음. 대부분 1명.
# *   Figure(2), (3) - 가족 크기에 따른 생존 비교. 가족이 4명인 경우 가장 생존확률이 높다. 가족수가 많아질수록(5~11) 생존확률 낮아진다. 가족수가 너무 작아도 너무 커도 생존확률은 작다

# %% [markdown]
# ## 2.8 Fare
# ### Fare 은 탑승요금. contious feature이다. histogram으로 그려보자

# %%
fig, ax=plt.subplots(1,1,figsize=(8,8))
g = sns.distplot(df_train['Fare'],color='b',label='Skewness: {:.2f}'.format(df_train['Fare'].skew()),ax=ax)
g= g.legend(loc='best')

# %% [markdown]
# ##### 위를 통해 distribution이 비대칭하다는 걸 알수있다.
# ##### outlier 영향을 줄이기 위해 Fare에 log를 취하자
# ##### pandas의 기능. dataFrame의 특정 columns에 함수를 적용
# ##### 아래의 map, apply를 사용
# #### 지금 하려는 것 : Fare columns의 데이터 모두에 log 취하자
# #### 파이썬의 lambda함수로 로그 적용하는 함수를 map에 인수로 넣자

# %%
df_test.loc[df_test.Fare.isnull(),'Fare'] = df_test['Fare'].mean()
#testset의 nan value를 평균값으로 치환

df_train['Fare'] = df_train['Fare'].map(lambda i : np.log(i) if i>0 else 0)
df_test['Fare'] = df_test['Fare'].map(lambda i: np.log(i) if i >0 else 0)

# %%
fig,ax= plt.subplots(1,1,figsize =(8,8))
g=sns.distplot(df_train['Fare'],color='b',label='Skewness : {:.2f}'.format(df_train['Fare'].skew()),ax=ax)
g=g.legend(loc='best')

# %% [markdown]
# ##### log 취해서 비대칭성 많이 사라짐
# ##### 이건 사실 feature engineering
# ##### 모델을 학습시키기 위해서 feature들에 여러 조작을 가하거나 새로운 feature을 추가하는 것을 feature engineering이라 한다.

# %% [markdown]
# # 2.9 Cabin
# ###이 feature는 NaN이 80%라서 저옵 얻기 쉽지 않다
# ### 그래서 모델에 포함시키지 않을 거다

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 0            1         0       3  ...  0.683603   NaN         S
# 1            2         1       1  ...  1.450832   C85         C
# 2            3         1       3  ...  0.727559   NaN         S
# 3            4         1       1  ...  1.379314  C123         S
# 4            5         0       3  ...  0.735091   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# ## 2.10 Ticket
# ##### NaN이 없다. string data라서 작업을 해줘야 모델에 사용가능
# ##### 아이디어가 필요함
# ##### 티켓의 어떤 특징에서 생존과 연결시킬 수 있을지 생각해봐라

# %%
df_train['Ticket'].value_counts()
# Out:
# CA. 2343            7
# 1601                7
# 347082              7
# CA 2144             6
# 347088              6
#                    ..
# PC 17599            1
# 234604              1
# 345770              1
# 250648              1
# SOTON/OQ 3101316    1
# Name: Ticket, Length: 681, dtype: int64

# %% [markdown]
# # 2부 시작

# %%
#패키지 설치
import numpy as np
import pandas as pd
from pandas import Series
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5) # 이 두줄은 본 필자가 항상 쓰는 방법입니다. matplotlib 의 기본 scheme 말고 seaborn scheme 을 세팅하고, 일일이 graph 의 font size 를 지정할 필요 없이 seaborn 의 font_scale 을 사용하면 편합니다.
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#데이터 프레임 불러오기

df_train['FamilySize'] = df_train['SibSp'] + df_train['Parch'] + 1 # 자신을 포함해야하니 1을 더합니다
df_test['FamilySize'] = df_test['SibSp'] + df_test['Parch'] + 1 # 자신을 포함해야하니 1을 더합니다

df_test.loc[df_test.Fare.isnull(), 'Fare'] = df_test['Fare'].mean()

df_train['Fare'] = df_train['Fare'].map(lambda i: np.log(i) if i > 0 else 0)
df_test['Fare'] = df_test['Fare'].map(lambda i: np.log(i) if i > 0 else 0)

# %% [markdown]
# # 3. Feature Engineering

# %% [markdown]
# ## 3.1 Fill Null data
# ## 3.1.1 Fill Null in Age using title
# ##### Age에는 null data가 177개
# ##### 여러 아이디어가 있다
# ##### title+statistics 사용해보자
# ##### title 이란 Miss,Mrr,Mrs 같은
# ##### pandas series에 data를 string으로 바꿔주는 str method
# ##### 정규표현식 적용해주는 extra method 가 있다
# ##### title을 추출해서 Initial column에 저장하자

# %%
df_train['Initial']=df_train.Name.str.extract('([A-Za-z]+)\.')
#extract the Salutations

df_test['Initial']=df_test.Name.str.extract('([A-Za-z]+)\.')

# %% [markdown]
# ##### pandas의 crosstab을 이용해서 추출한 Initial과 Sex간 count를 살펴보자
